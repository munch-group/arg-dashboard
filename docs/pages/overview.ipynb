# %% [raw]
# ---
# title: Overview
# aliases:
#   - ../index.html
# jupyter:
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %% [markdown]
# **arg-dashboard** lets you ...
#
# {{< lipsum 1 >}}
#
# ## Installation
#
# ::: {.panel-tabset}
#
# ## pixi
#
# ```bash
# pixi workspace channel add munch-group
# pixi add arg-dashboard
# ```
#
# ## conda
#
# ```bash
# conda install -c munch-group arg-dashboard
# ```
#
# ## pip
#
# ```bash
# pip install arg-dashboard
# ```
#
# :::
#
#
# ## Basic use
#
# ```python
#
# ```
#
# ## Some use case
#
# The [functionname function](`arg_dashboard.modulename.functionname`) does ... [](`arg_dashboard.modulename.functionname`) does ... [](`~arg_dashboard.modulename.functionname`) does ...
#
# {{< lipsum 1 >}}

# %%
# from arg_dashboard.modulename import functionname
# functionname(3, 4)

# %% [markdown]
# {{< lipsum 1 >}}
#
# ```yaml
# contents:
#   - MdRenderer
# ```
#
# {{< lipsum 1 >}}
#
# ## Learning more
#
# Go [to the anvanced page](overview.ipynb) to learn how to ...
#
# * [Examples page](overview.ipynb): sites using quartodoc.
