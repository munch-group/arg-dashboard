# %%
import os
os.environ['no_proxy'] = os.environ.get('no_proxy', '') + ',127.0.0.1,localhost'
from argdash import arg_dashboard

arg_dashboard.app.run(mode='inline', jupyter_height=800)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/argdash/.pixi/envs/default/lib/python3.14/site-packages/werkzeug/serving.py:759, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     758 try:
# --> 759     self.server_bind()
#     760     self.server_activate()
#
# File ~/argdash/.pixi/envs/default/lib/python3.14/http/server.py:148, in HTTPServer.server_bind(self)
#     147 """Override server_bind to store the server name."""
# --> 148 socketserver.TCPServer.server_bind(self)
#     149 host, port = self.server_address[:2]
#
# File ~/argdash/.pixi/envs/default/lib/python3.14/socketserver.py:478, in TCPServer.server_bind(self)
#     477     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 478 self.socket.bind(self.server_address)
#     479 self.server_address = self.socket.getsockname()
#
# ...
